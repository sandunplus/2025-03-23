# %% [markdown]
# # <span style="color:#0b486b">Data Science Concepts</span>
#
# ---
#
# ---

# %% [markdown]
# ## <span style="color:#0b486b">Practical Session : Plots</span>
#
# **The purpose of this session is to teach you:**
#
# 1. How to draw and manipulate
#     1. Pie chart
#     2. Wordcloud
#     3. Bar charts
#     4. step chart
#     5. histogram
#     6. boxplot
#     7. scatter plot
# 2. Pearson-r correlation coefficient
# 3. Spearman's rank coefficient
# ---

# %% [markdown]
# You have already been thought about different sorts of plots, how they help to get a better understanding of the data, and when to use which. In this practical session we will work with `matplotlib` package to learn more about plotting in Python.

# %%
import numpy as np
import csv

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## <span style="color:#0b486b">1. Pie Chart</span>
#
# Suppose you have the frequency count of a variable (e.g. hair_colour). Draw a pie chart to explain it.

# %%
labels = ['Black', 'Red', 'Brown']

# frequency count
hair_colour_freq = [5, 3, 2]  # Black, Red, Brown

# colours
colours = ['yellowgreen', 'gold', 'lightskyblue']

fig, ax = plt.subplots(figsize=(5, 5))
ax.pie(hair_colour_freq, colors=colours, labels=labels, shadow=True,
       explode=(0, 0.1, 0), startangle=90, autopct="%1.1f")
# Out:
# ([<matplotlib.patches.Wedge at 0x7d8419b64440>,
#   <matplotlib.patches.Wedge at 0x7d8419b2f440>,
#   <matplotlib.patches.Wedge at 0x7d8419b8ade0>],
#  [Text(-1.0999999999999959, -9.616505800409723e-08, 'Black'),
#   Text(0.9708203360765971, -0.7053423814433124, 'Red'),
#   Text(0.6465637046702114, 0.8899187467421573, 'Brown')],
#  [Text(-0.5999999999999978, -5.2453668002234845e-08, '50.0'),
#   Text(0.5663118627113483, -0.4114497225085989, '30.0'),
#   Text(0.35267111163829706, 0.4854102254957221, '20.0')])

# %% [markdown]
# What if we have too many tags and sectors?

# %%
# Excellence in Reasearch Australia
labels = ['HEALTH', 'ENGINEERING', 'COMPUTER SCIENCES', 'HUMAN SOCIETY',
          'TOURISM SERVICES', 'EDUCATION', 'CHEMISTRY', 'BIOLOGY', 'PSYCHOLOGY',
          'CREATIVE ARTS', 'LINGUISTICS', 'BUILT ENVIRONMENT', 'HISTORY',
          'ECONOMICS', 'PHILOSOPHY', 'AGRICULTURE', 'ENVIRONMENT', 'TECHNOLOGY',
          'LAW', 'MATHS', 'EARTH SCIENCES', 'PHYSICS']


# frequency count
xx = [2625.179999, 1306.259999, 1187.039999, 1166.04, 980.8599997, 810.5999998,
      725.6399996, 678.7899998, 436.5999997, 404.3299999, 348.01, 304.33, 294.19,
      293.02, 282.31, 228.21, 197.3399999, 164.0599998, 157, 50.49999998, 49.60999999, 48.08000005]

fig, ax = plt.subplots(figsize=(15, 15))
ax.pie(xx, labels=labels, autopct="%1.1f");

# %% [markdown]
# ---
# ## <span style="color:#0b486b">2. Bar Chart</span>
#
# Use the hair colour data to draw a bar chart.

# %%
labels = ['Black', 'Red', 'Brown']
colours = ['black', 'red', 'brown']

hair_colour_freq = [5, 3, 2]
x_pos = np.arange(len(hair_colour_freq))

fig, ax = plt.subplots(figsize=(7, 5))
ax.bar(x_pos, hair_colour_freq, color=colours, align='center')

ax.set_xlabel("Hair colours")
ax.set_ylabel("Number of participants")
ax.set_title("Hair Colour Distribution")

ax.set_xticks(x_pos)
ax.set_xticklabels(labels)
# Out:
# [Text(0, 0, 'Black'), Text(1, 0, 'Red'), Text(2, 0, 'Brown')]

# %% [markdown]
# **Exercise:** Now suppose we have the hair colour distribution across genders, so we can plot grouped bar charts. Plot a grouped bar chart to show the distribution of colours acros genders.

# %%
"""
        black  red  brown
Male      4     1     3
Female    1     2     2

"""

data = np.array([[4, 1, 3],
               [1, 2, 2]])

x_pos = np.arange(2)
width = 0.2

fig, ax = plt.subplots(figsize=(7, 5), dpi=300)
ax.bar(x_pos, data[:, 0], width=width, color='black', align='center', label='Black')
ax.bar(x_pos+width, data[:, 1], width=width, color='red', align='center', label='Red')
ax.bar(x_pos+2*width, data[:, 2], width=width, color='brown', align='center', label='Brown')

labels = ['Male', 'Female']
ax.set_xticks(x_pos + width)
ax.set_xticklabels(labels, size=15)

ax.legend()

# %% [markdown]
# **Exercise:** Can we plot it more intelligently? We are doing the same thing multiple times! Is it a good idea to use a loop?

# %%
"""
        black  red  brown
Male      4     1     3
Female    1     2     2

Insert your code here
"""
data = np.array([[4, 1, 3],
               [1, 2, 2]])

x_pos = np.arange(2)
width = 0.2

fig, ax = plt.subplots(figsize=(7, 5), dpi=300)

colours = ['black', 'red', 'brown']
for i in range(3):
  ax.bar(x_pos+i*width, data[:,i-1], width=width, color=colours[i-1], align='center', label=colours[i-1])

labels = ['Male', 'Female']
ax.set_xticks(x_pos + width)
ax.set_xticklabels(labels, size=15)

ax.legend()

# %% [markdown]
# **Exercise:** What if we want to group the bar charts based on the hair colour?

# %%
"""
        black  red  brown
Male      4     1     3
Female    1     2     2

Insert your code here
"""
data = np.array([[4, 1, 3],
               [1, 2, 2]])

x_pos = np.arange(3)
width = 0.4

fig, ax = plt.subplots(figsize=(7, 5), dpi=300)
ax.bar(x_pos, data[0,:], width=width, color='black', align='center', label='Male')
ax.bar(x_pos+width, data[1,:], width=width, color='red', align='center', label='Female')

labels = ['black', 'red','brown']
ax.set_xticks(x_pos + width)
ax.set_xticklabels(labels, size=15)

ax.legend()

# %% [markdown]
# #### Stacked bar chart
#
# **Exercise:** The other type of bar chart is stacked bar chart. Draw a stacked bar plot of the hair colour data grouped on hair colours.

# %%
"""
        black  red  brown
Male      4     1     3
Female    1     2     2

"""

labels = ['Black', 'Red', 'Brown']
data = np.array([[4, 1, 3],
                 [1, 2, 2]])

n_groups, n_colours = data.shape
x_pos = np.arange(n_colours)
width = 0.4

fig, ax = plt.subplots()

ax.bar(x_pos, data[0, :], color='r', width=width, align='center', label='Male')
ax.bar(x_pos, data[1, :], color='y', bottom=data[0, :], width=width, align='center', label='Female')
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# **Exercise:** Draw a stacked bar plot grouped on the gender.

# %%
"""
        black  red  brown
Male      4     1     3
Female    1     2     2

Insert your code here
"""
labels = ['Male', 'Female']
data = np.array([[4, 1, 3],
                 [1, 2, 2]])

n_groups, n_colours = data.shape
x_pos = np.arange(2)
width = 0.4

fig, ax = plt.subplots()

ax.bar(x_pos, data[:,0], color='r', width=width, align='center', label='Black')
ax.bar(x_pos, data[:,1], color='y', bottom=data[:,0], width=width, align='center', label='Red')
ax.bar(x_pos, data[:,2], color='b', bottom=data[:,1], width=width, align='center', label='Brown')
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ### subplots
#
# **Exercise:** Use subplots to draw two graphs next to each other

# %%
labels = ['Black', 'Red', 'Brown']
male_freq = [4, 1, 3]
female_freq = [1, 2, 2]
x_pos = np.arange(len(labels))

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))

# Your code here
# 1. using ax[0].bar and ax[1].bar to plot bar charts for the first and the second subplots
ax[0].bar(x_pos, male_freq, color='skyblue', label='Male')
ax[1].bar(x_pos, female_freq, color='salmon', label='Female')

# 2. set xlabel, ylabel and title for each subplot
ax[0].set_xlabel('Hair Color')
ax[0].set_ylabel('Count')
ax[0].set_title('Male Hair Color Frequency')
ax[1].set_xlabel('Hair Color')
ax[1].set_ylabel('Count')
ax[1].set_title('Female Hair Color Frequency')
# 3. set xtick and xticklabels for each subplot
ax[0].set_xticks(x_pos)
ax[0].set_xticklabels(labels)
ax[1].set_xticks(x_pos)
ax[1].set_xticklabels(labels)
# 4. set legen for each subplot
ax[0].legend()
ax[1].legend()

# %% [markdown]
# **Exercise:** What if we have too many groups? Draw a bar chart for the Excellence in Research Australia data.

# %%
# Excellence in Reasearch Australia
labels = ['HEALTH', 'ENGINEERING', 'COMPUTER SCIENCES', 'HUMAN SOCIETY',
          'TOURISM SERVICES', 'EDUCATION', 'CHEMISTRY', 'BIOLOGY', 'PSYCHOLOGY',
          'CREATIVE ARTS', 'LINGUISTICS', 'BUILT ENVIRONMENT', 'HISTORY',
          'ECONOMICS', 'PHILOSOPHY', 'AGRICULTURE', 'ENVIRONMENT', 'TECHNOLOGY',
          'LAW', 'MATHS', 'EARTH SCIENCES', 'PHYSICS']


# frequency count
xx = [2625.179999, 1306.259999, 1187.039999, 1166.04, 980.8599997, 810.5999998,
      725.6399996, 678.7899998, 436.5999997, 404.3299999, 348.01, 304.33, 294.19,
      293.02, 282.31, 228.21, 197.3399999, 164.0599998, 157, 50.49999998, 49.60999999, 48.08000005]

# Your code here
x_pos = np.arange(len(xx))

fig,ax = plt.subplots(figsize=(7, 5))
ax.bar(x_pos, xx, color='salmon', align='center')

ax.set_xlabel("Research Type")
ax.set_ylabel("Count")
ax.set_title("Excellence in Research Australia")

ax.set_xticks(x_pos)
ax.set_xticklabels(labels)
# Out:
# [Text(0, 0, 'HEALTH'),
#  Text(1, 0, 'ENGINEERING'),
#  Text(2, 0, 'COMPUTER SCIENCES'),
#  Text(3, 0, 'HUMAN SOCIETY'),
#  Text(4, 0, 'TOURISM SERVICES'),
#  Text(5, 0, 'EDUCATION'),
#  Text(6, 0, 'CHEMISTRY'),
#  Text(7, 0, 'BIOLOGY'),
#  Text(8, 0, 'PSYCHOLOGY'),
#  Text(9, 0, 'CREATIVE ARTS'),
#  Text(10, 0, 'LINGUISTICS'),
#  Text(11, 0, 'BUILT ENVIRONMENT'),
#  Text(12, 0, 'HISTORY'),
#  Text(13, 0, 'ECONOMICS'),
#  Text(14, 0, 'PHILOSOPHY'),
#  Text(15, 0, 'AGRICULTURE'),
#  Text(16, 0, 'ENVIRONMENT'),
#  Text(17, 0, 'TECHNOLOGY'),
#  Text(18, 0, 'LAW'),
#  Text(19, 0, 'MATHS'),
#  Text(20, 0, 'EARTH SCIENCES'),
#  Text(21, 0, 'PHYSICS')]

# %% [markdown]
# ---
# ## <span style="color:#0b486b">3. Wordcloud</span>
#
# As you saw, pie-chart is not very helpful when we have too many sectors. It is hard to read and visually ugly. Instead we can use wordcloud representation. A useful tool is [wordclouds.com](http://wordclouds.com).
#
# **Exercise:** Run the cell below, then go to [wordclouds.com](http://wordclouds.com) and use it to create a wordcloud for the output of the cell.
#
# **Note:** Go to the website and choose `File`, click `Paste/Type text` and then paste the text to the box and click `Apply`

# %%
for i in range(len(xx)):
    print("{} {}".format(xx[i], labels[i]))
# Out:
# 2625.179999 HEALTH
# 1306.259999 ENGINEERING
# 1187.039999 COMPUTER SCIENCES
# 1166.04 HUMAN SOCIETY
# 980.8599997 TOURISM SERVICES
# 810.5999998 EDUCATION
# 725.6399996 CHEMISTRY
# 678.7899998 BIOLOGY
# 436.5999997 PSYCHOLOGY
# 404.3299999 CREATIVE ARTS
# 348.01 LINGUISTICS
# 304.33 BUILT ENVIRONMENT
# 294.19 HISTORY
# 293.02 ECONOMICS
# 282.31 PHILOSOPHY
# 228.21 AGRICULTURE
# 197.3399999 ENVIRONMENT
# 164.0599998 TECHNOLOGY
# 157 LAW
# 50.49999998 MATHS
# 49.60999999 EARTH SCIENCES
# 48.08000005 PHYSICS

# %% [markdown]
# ---
# ## <span style="color:#0b486b">4. Step plot</span>
#
# **Exercise:** Draw a step plot for the seatbelt data provided in the lecture.

# %%
freq = np.array([0, 2, 1, 5, 7])
np.cumsum(freq)
# Out:
# array([ 0,  2,  3,  8, 15])

# %%
freq_cumsum = np.cumsum(freq)
labels = ['Never', 'Rarely', 'Sometimes', 'Most-times', 'Always']
x_pos = np.arange(len(freq))

fig, ax = plt.subplots()
ax.step(x_pos, freq_cumsum, where='mid')


# Your code here
# Set xlabel, ylabel, xticks and xticklabels for the figure
ax.set_xlabel('Seatbelt')
ax.set_ylabel('Number of participants')

ax.set_xticks(x_pos)
ax.set_xticklabels(labels)
# Out:
# [Text(0, 0, 'Never'),
#  Text(1, 0, 'Rarely'),
#  Text(2, 0, 'Sometimes'),
#  Text(3, 0, 'Most-times'),
#  Text(4, 0, 'Always')]

# %% [markdown]
# ---
# ## <span style="color:#0b486b">5. Histogram</span>
#
# **Exercise:** Draw a histogram of scores on Math test provided in the cell below.

# %%
scores = np.random.normal(loc=5, size=100)

# Your code here
# Draw a histogram of *scores* array
# Hint: you might use numpy.unique, which returns unique scores and their counts.
uniqueScores = np.unique(scores)

x_pos = np.arange(len(uniqueScores))

fig,ax = plt.subplots(figsize=(7, 5))
ax.hist(uniqueScores, bins=10, color='salmon', edgecolor='salmon')

ax.set_xlabel("Scores")
ax.set_ylabel("Values")
ax.set_title("Scores")

ax.set_xticks(x_pos)
# Out:
# [<matplotlib.axis.XTick at 0x7d84197969c0>,
#  <matplotlib.axis.XTick at 0x7d8419b0c200>,
#  <matplotlib.axis.XTick at 0x7d8419ab6360>,
#  <matplotlib.axis.XTick at 0x7d84195e7080>,
#  <matplotlib.axis.XTick at 0x7d84195e7aa0>,
#  <matplotlib.axis.XTick at 0x7d84195e63c0>,
#  <matplotlib.axis.XTick at 0x7d8419618830>,
#  <matplotlib.axis.XTick at 0x7d84196192e0>,
#  <matplotlib.axis.XTick at 0x7d8419619dc0>,
#  <matplotlib.axis.XTick at 0x7d841961a8a0>,
#  <matplotlib.axis.XTick at 0x7d8419618b60>,
#  <matplotlib.axis.XTick at 0x7d841961b2f0>,
#  <matplotlib.axis.XTick at 0x7d841961bc80>,
#  <matplotlib.axis.XTick at 0x7d8419630770>,
#  <matplotlib.axis.XTick at 0x7d8419631130>,
#  <matplotlib.axis.XTick at 0x7d84195e7860>,
#  <matplotlib.axis.XTick at 0x7d8419631880>,
#  <matplotlib.axis.XTick at 0x7d84196322a0>,
#  <matplotlib.axis.XTick at 0x7d8419632c90>,
#  <matplotlib.axis.XTick at 0x7d8419a1cfe0>,
#  <matplotlib.axis.XTick at 0x7d8419631520>,
#  <matplotlib.axis.XTick at 0x7d8419633fb0>,
#  <matplotlib.axis.XTick at 0x7d841964c9e0>,
#  <matplotlib.axis.XTick at 0x7d841964d460>,
#  <matplotlib.axis.XTick at 0x7d8419632ea0>,
#  <matplotlib.axis.XTick at 0x7d841964de50>,
#  <matplotlib.axis.XTick at 0x7d841964e8a0>,
#  <matplotlib.axis.XTick at 0x7d841964f350>,
#  <matplotlib.axis.XTick at 0x7d841964fda0>,
#  <matplotlib.axis.XTick at 0x7d841964ec30>,
#  <matplotlib.axis.XTick at 0x7d8419668920>,
#  <matplotlib.axis.XTick at 0x7d8419669220>,
#  <matplotlib.axis.XTick at 0x7d8419669ca0>,
#  <matplotlib.axis.XTick at 0x7d841966a6f0>,
#  <matplotlib.axis.XTick at 0x7d841966a0f0>,
#  <matplotlib.axis.XTick at 0x7d841966b170>,
#  <matplotlib.axis.XTick at 0x7d841966bbc0>,
#  <matplotlib.axis.XTick at 0x7d8419684620>,
#  <matplotlib.axis.XTick at 0x7d84196850d0>,
#  <matplotlib.axis.XTick at 0x7d8419669880>,
#  <matplotlib.axis.XTick at 0x7d8419685b20>,
#  <matplotlib.axis.XTick at 0x7d84196865a0>,
#  <matplotlib.axis.XTick at 0x7d8419686ff0>,
#  <matplotlib.axis.XTick at 0x7d8419687a10>,
#  <matplotlib.axis.XTick at 0x7d8419685e50>,
#  <matplotlib.axis.XTick at 0x7d84194a4590>,
#  <matplotlib.axis.XTick at 0x7d84194a5010>,
#  <matplotlib.axis.XTick at 0x7d84194a5a60>,
#  <matplotlib.axis.XTick at 0x7d84194a6480>,
#  <matplotlib.axis.XTick at 0x7d84194a4bc0>,
#  <matplotlib.axis.XTick at 0x7d84194a6e70>,
#  <matplotlib.axis.XTick at 0x7d84194a78f0>,
#  <matplotlib.axis.XTick at 0x7d84194b8350>,
#  <matplotlib.axis.XTick at 0x7d84194a7fb0>,
#  <matplotlib.axis.XTick at 0x7d84194a4200>,
#  <matplotlib.axis.XTick at 0x7d84194b97f0>,
#  <matplotlib.axis.XTick at 0x7d84194ba210>,
#  <matplotlib.axis.XTick at 0x7d84194bad20>,
#  <matplotlib.axis.XTick at 0x7d84194a6780>,
#  <matplotlib.axis.XTick at 0x7d84194baf30>,
#  <matplotlib.axis.XTick at 0x7d84194bb6b0>,
#  <matplotlib.axis.XTick at 0x7d84194bbfb0>,
#  <matplotlib.axis.XTick at 0x7d84194d4a40>,
#  <matplotlib.axis.XTick at 0x7d84194b9f40>,
#  <matplotlib.axis.XTick at 0x7d84194d5430>,
#  <matplotlib.axis.XTick at 0x7d84194d5ee0>,
#  <matplotlib.axis.XTick at 0x7d84194d6930>,
#  <matplotlib.axis.XTick at 0x7d84194d73b0>,
#  <matplotlib.axis.XTick at 0x7d84194d6330>,
#  <matplotlib.axis.XTick at 0x7d84194d7f50>,
#  <matplotlib.axis.XTick at 0x7d84194f4980>,
#  <matplotlib.axis.XTick at 0x7d84194f53d0>,
#  <matplotlib.axis.XTick at 0x7d84194f5df0>,
#  <matplotlib.axis.XTick at 0x7d84194f5040>,
#  <matplotlib.axis.XTick at 0x7d84194f6810>,
#  <matplotlib.axis.XTick at 0x7d84194f7260>,
#  <matplotlib.axis.XTick at 0x7d84194f7c80>,
#  <matplotlib.axis.XTick at 0x7d8419508740>,
#  <matplotlib.axis.XTick at 0x7d84194f4bf0>,
#  <matplotlib.axis.XTick at 0x7d8419509100>,
#  <matplotlib.axis.XTick at 0x7d8419509b20>,
#  <matplotlib.axis.XTick at 0x7d841950a5a0>,
#  <matplotlib.axis.XTick at 0x7d841950b020>,
#  <matplotlib.axis.XTick at 0x7d8419509340>,
#  <matplotlib.axis.XTick at 0x7d841950b920>,
#  <matplotlib.axis.XTick at 0x7d8419524380>,
#  <matplotlib.axis.XTick at 0x7d8419524e30>,
#  <matplotlib.axis.XTick at 0x7d841950b230>,
#  <matplotlib.axis.XTick at 0x7d84195257c0>,
#  <matplotlib.axis.XTick at 0x7d8419526210>,
#  <matplotlib.axis.XTick at 0x7d8419526c90>,
#  <matplotlib.axis.XTick at 0x7d8419527770>,
#  <matplotlib.axis.XTick at 0x7d84195268d0>,
#  <matplotlib.axis.XTick at 0x7d84195442c0>,
#  <matplotlib.axis.XTick at 0x7d8419544d70>,
#  <matplotlib.axis.XTick at 0x7d84195457c0>,
#  <matplotlib.axis.XTick at 0x7d84195461e0>,
#  <matplotlib.axis.XTick at 0x7d8419545a30>,
#  <matplotlib.axis.XTick at 0x7d8419546c00>,
#  <matplotlib.axis.XTick at 0x7d8419547650>]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ---
# ## <span style="color:#0b486b">6. Boxplot</span>
# **Exercise:** Draw a box plot for scores on Math test from the previous exercise.

# %%
# Your code here

plt.figure(figsize=(7, 5))
plt.boxplot(uniqueScores)

plt.xlabel("Scores")
plt.title("Box Plot of Scores")
plt.show()

# %% [markdown]
# ---
# ## <span style="color:#0b486b">7. Scatter plot</span>
#
# **Exercise:** Draw a scatter plot of the car weights and their fuel consumption as displayed in the lecture.

# %%
# Read the data
datafile = "/content/drive/MyDrive/DataScience/Corrected/auto.csv"
data = np.genfromtxt(datafile, delimiter=',')
data = []
with open(datafile, 'r') as fp:
    reader = csv.reader(fp, delimiter=',')
    for row in reader:
        data.append(row)

miles = [float(dd[1]) for dd in data[1:]]
weights = [float(dd[5]) for dd in data[1:]]

# %%
# Your code here
# Draw a scatter plot of the 2 arrays: weights and miles from the previous code cell

plt.figure(figsize=(7, 5))
plt.scatter(miles, weights)

plt.xlabel("miles")
plt.ylabel("weights")
plt.title("Fual consumption")
# Out:
# Text(0.5, 1.0, 'Fual consumption')

# %% [markdown]
# ---
# ## <span style="color:#0b486b">8. Pearson's-r Correlation coefficinet</span>

# %% [markdown]
# We assume $X=\left\{ X_{1},\ldots,X_{n}\right\}$ and $Y=\left\{ Y_{1},\ldots,Y_{n}\right\}$. Then Pearson-r correlation coefficient is defined as
# $$ \rho(X,Y) = \frac{\text{cov}(X,Y)}{\sigma_X \sigma_Y} =  \frac{\sum_{i=1}^n (X_i - \bar{X})(Y_i - \bar{Y})}{\sqrt{\sum_{i=1}^n(X_i-\bar{X})^2} \sqrt{\sum_{i=1}^n(Y_i-\bar{Y})^2}} $$

# %% [markdown]
# **Exercise:** Use the car data and find the Pearson's-r correlation coefficient between car weights and fuel consumption.

# %%
# Your code here
# find the Pearson's-r correlation coefficient between
# ... the two arrays weights and miles from previous section.
r = np.corrcoef(miles, weights)[0,1]

# %% [markdown]
# **Exercise:** Find the Pearson's-r coefficient for two linearly dependent variables. Add some noise and see the effect of varying the noise. What is positive correlation? What is negative correlation?

# %%
import scipy
from scipy import stats
# Generating xx and yy, which are two linearly dependent variables with some noise
xx = np.arange(-5, 5, 0.1)
pp = 1.5  # level of noise
yy = xx + np.random.normal(0, pp, size=len(xx))

plt.figure(figsize=(7, 5))
plt.scatter(xx, yy)

plt.xlabel("miles")
plt.ylabel("weights")
plt.title("Fual consumption")
# Out:
# Text(0.5, 1.0, 'Fual consumption')

# %% [markdown]
# Pearson's r coefficient is limited to analyse the linear correlation between two variables. It is not capable to show the non-linear dependency. Investigate the Pearson's r coefficient between two variables that are correlated non-linearly.

# %%
# generate some data, first for X
xx = np.arange(-5, 5, 0.1)

# assume Y = 2Y + some perturbation
pp = 1.5  # level of noise
yy = xx**2 + np.random.normal(0, pp, size=len(xx))

# Your code here
# visualize the data (xx and yy) by a scatter plot
plt.figure(figsize=(7, 5))
plt.scatter(xx, yy)

plt.xlabel("miles")
plt.ylabel("weights")
plt.title("Fual consumption")
# Out:
# Text(0.5, 1.0, 'Fual consumption')

# %%
# Your code here
# Pearson's coefficient between xx and yy
r = np.corrcoef(xx, yy)[0,1]

# %% [markdown]
# ---
# ## <span style="color:#0b486b">9. Spearman's rank coefficient</span>
#
# **Exercise**: Spearman's rank coefficient is used for discrete data. Find the Spearman's rank between horse power and number of cylinders of the car data.

# %%
horse = np.array([float(dd[4]) for dd in data[1:]])
cylinder = np.array([float(dd[2]) for dd in data[1:]])

# Your code here
# Draw a scatter plot for horse power and the number of cylinders of the cars.

plt.figure(figsize=(7, 5))
plt.scatter(horse, cylinder)

plt.xlabel("horse")
plt.ylabel("cylinder")
plt.title("horse power and the number of cylinders")
# Print the Spearman's rank

spearmanRank = scipy.stats.spearmanr(horse, cylinder)
print("Spearman's rank",spearmanRank)
# Out:
# Spearman's rank SignificanceResult(statistic=np.float64(-0.6581423040218369), pvalue=np.float64(5.157840368072828e-50))
